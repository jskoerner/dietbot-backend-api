# %% [markdown]
# <a href="https://colab.research.google.com/github/jskoerner/dietbot-backend-api/blob/main/dietbot_batch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, json, pandas as pd


API_URL = "https://dietbot-backend-210506815248.us-central1.run.app/query"


prompts = [
    "Is dietary iron poorly absorbed?",
    "Give me 3 high‑protein vegetarian snacks.",
    "How much vitamin D is safe per day?",
]

results = []

for p in prompts:
    payload = {"query": p}
    resp = requests.post(API_URL, json=payload, timeout=120)
    resp.raise_for_status()
    data = resp.json()
    results.append({
        "prompt": p,
        "answer": data.get("final_answer"),
        "reasoning": data.get("reasoning"),
        "context_used": data.get("context_used")
    })

df = pd.DataFrame(results)
df
# Out:
#                                       prompt  \
# 0           Is dietary iron poorly absorbed?
# 1  Give me 3 high‑protein vegetarian snacks.
# 2        How much vitamin D is safe per day?
#
#                                               answer  \
# 0  Yes, dietary iron is poorly absorbed from food...
# 1  1. **Edamame**: Steamed and lightly salted, pa...
# 2  For most adults, a daily intake of 400 IU (10 ...
#
#                                            reasoning  \
# 0  Identified intent: Educational-Content. Dietar...
# 1  Identified intent: Meal-Planning-Recipes. Base...
# 2  Identified intent: Educational-Content. The re...
#
#                                         context_used
# 0  Knowledge Source (score: 0.66): Food and Nutri...
# 1  Knowledge Source (score: 0.66): Food and Nutri...
# 2  Knowledge Source (score: 0.49): Food and Nutri...
